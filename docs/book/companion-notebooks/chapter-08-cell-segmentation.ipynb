# %% [markdown]
# # Chapter 8: Cell Segmentation
#
# **Companion notebook for Chapter 8**
#
# **IMPORTANT**: Requires deployed MCP servers on your GCP project.
#
# See [`README.md`](./README.md) for complete setup instructions.

# %%
import os
from anthropic import Anthropic

# Configuration
os.environ["ANTHROPIC_API_KEY"] = "your_key_here"

# mcp-deepcell server URL
MCP_SERVER_URL = "https://YOUR_SERVER-YOUR_PROJECT.run.app/sse"

client = Anthropic()
print("✅ Configuration loaded")

# %% [markdown]
# ## Exercise 1: Nuclear Segmentation
#
# ## Exercise 2: Phenotype Classification
